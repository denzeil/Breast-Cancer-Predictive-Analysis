# %% [markdown]
# # Cancer Patients Data Analysis by Caleb Denzeil
#  - This Dataset contains information about patients that have cancer and whether it's benign or malignant. It also includes the different measurements of tumors for the example radius mean and perimeter.
#  - The Dataset has 33 features and 569 rows

# %% [markdown]
# # Preliminary Gathering

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import and load the data
Cancer=pd.read_csv('data.csv')
Cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Assess the data

# %%
#Create a copy of the original dataset
Cancer_copy=Cancer.copy()

# %%
#Look into the data types of each column
Cancer_copy.info()
pd.set_option('display.max_columns',None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
Cancer_copy.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
#Check for null values
Cancer_copy.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# > The dataset has no null values apart from column Unnamed: 32

# %%
Cancer_copy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > The dataset has no duplicate values

# %%
#Describe the dataset
Cancer_copy.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Data Tidiness issues

# %% [markdown]
# - Unnamed Column has null values

# %% [markdown]
# - The values in the diagnosis column should be represented in another column as 0 and 1

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### Drop Unnamed: 32 column

# %%
Cancer_copy.drop(['Unnamed: 32'],axis='columns',inplace=True)

# %%
#Test
Cancer_copy.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Map B and M values in the `diagnosis` column to another column called `Final` as 0 and 1

# %%
Cancer_copy['Final']=Cancer_copy['diagnosis'].map({'B':0,'M':1})

# %%
#Test
Cancer_copy.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Q1. How many People benign and malignant tumors?

# %%
#grid style
sns.set_style('darkgrid')
color=sns.color_palette()[0]
#plot a bar graph
sns.countplot(data=Cancer_copy,x='diagnosis',color=color)
plt.title('Diagnosis');

# %%
Cancer_copy.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# > 357 people have benign tumors while 212 malignant. There are more people that have benign tumors over malignant from the bar graph

# %% [markdown]
# ## Q2. What is the distribution for radius_mean and perimeter_mean?

# %%
sns.histplot(data=Cancer_copy,x='radius_mean',hue='diagnosis')
plt.title('Distribution for radius mean');

# %%
sns.histplot(data=Cancer_copy,x='perimeter_mean',hue='diagnosis');
plt.title('Distribution for radius mean');

# %% [markdown]
# > Most Patients with benign tumors have a radius mean that ranges within 11-14 while malignant 15-20. While the perimeter mean for benign tumors ranges from 75-90 and malignant 85-140.
#
# >There are patients that have almost the same radius(11-16) and perimeter(80-105) mean but have benign and malignant tumors.

# %%
#plt.figure(figsize=(30,30))
columns=Cancer_copy.columns[2:12]
sns.heatmap(Cancer_copy[columns].corr(),annot=True,cmap='viridis_r');

# %%
Cancer_copy[columns].corr()
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.323782        0.997855   0.987357
# texture_mean               0.323782      1.000000        0.329533   0.321086
# perimeter_mean             0.997855      0.329533        1.000000   0.986507
# area_mean                  0.987357      0.321086        0.986507   1.000000
# smoothness_mean            0.170581     -0.023389        0.207278   0.177028
# compactness_mean           0.506124      0.236702        0.556936   0.498502
# concavity_mean             0.676764      0.302418        0.716136   0.685983
# concave points_mean        0.822529      0.293464        0.850977   0.823269
# symmetry_mean              0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean    -0.311631     -0.076437       -0.261477  -0.283110
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %% [markdown]
# # Predictive analysis

# %% [markdown]
# ## Using a random forest

# %%
# Identify the independent variables and labels
x=Cancer_copy.loc[:,"radius_mean":"fractal_dimension_worst"]
y=Cancer_copy["Final"]

# %%
#split the dataset and import the random forest model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#Fit the model
Forest=RandomForestClassifier()
Forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Evaluate the model on the training and test data
Forest.score(x_test,y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# > The model has an accuracy of 0.97 which calculates to a a 97% accuracy which is pretty good using random forests

# %%
#Calculate the confusion matrix
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
y_pred=Forest.predict(x_test)
print(confusion_matrix(y_test,y_pred))
# Out:
# [[77  0]
#  [ 2 35]]

# %% [markdown]
# > From the confusion matrix, 75 True positives(The model correctly predicted 75 patients had malignant tumors).
#
# > 0 False positives(The model did not falsely predict that a patient had a malignant tumor).
#
# > 3 False Negatives(The model incorrectly predicted that 3 patients did not have benign tumors).
#
# > 36 True Negatives(The model correctly predicted that 36 patients had benign tumors).

# %%
#Get the classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        77
#            1       1.00      0.95      0.97        37
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# >For class 0, the precision is 0.97, which means that out of all instances predicted as class 0, 97% were actually class 0.
# For class 1, the precision is 1.00, indicating that all instances predicted as class 1 were indeed class 1.
#
# >For class 0, the recall is 1.00, implying that all actual class 0 instances were correctly identified.
# For class 1, the recall is 0.95, indicating that 95% of the actual class 1 instances were correctly identified.
#
# >For class 0, the F1-score is 0.99, which combines precision and recall into a single metric, indicating high performance.
# For class 1, the F1-score is 0.97, reflecting a good balance between precision and recall.
#
# >For class 0, the support is 77, indicating that there are 77 instances of class 0 in the dataset.
# For class 1, the support is 37, indicating that there are 37 instances of class 1 in the dataset.
#
# >The macro average precision, recall, and F1-score are 0.99, 0.97, and 0.98, respectively, indicating good overall performance across all classes.
#
# >The weighted average precision, recall, and F1-score are 0.98, 0.98, and 0.98, respectively, providing an overall performance measure considering the class imbalance.
#
# >Overall, the classification report indicates that the model performs well in both classes, with high precision, recall, and F1-scores. The model has a precision of 98% which means that it predicted most of the outcomes correctly. In general the model performed well.

# %%
##Cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
kfold=KFold(n_splits=4,shuffle=True,random_state=0)

scores= cross_val_score(Forest,x,y,cv=kfold)

best=['{:.2f}'.format(score) for score in scores]

print(f"Cross validation scores: {best}")
print(f"Mean Cross validation score: {np.round(scores.mean(),2)}")
# Out:
# Cross validation scores: ['0.98', '0.96', '0.93', '0.97']
# Mean Cross validation score: 0.96

# %% [markdown]
# > Using the cross-validation mean, the model is expected to be around 96%  accurate on average
